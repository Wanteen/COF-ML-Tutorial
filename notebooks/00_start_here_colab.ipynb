# %% [markdown]
# # COF-ML-Tutorial — Colab 中文入口
#
# 推荐从 00 开始按编号学习。01–02 很短，目标是尽快完成第一次回归和分类。

# %%
import os, subprocess
repo='/content/COF-ML-Tutorial'
if not os.path.exists(repo): subprocess.run(['git','clone','https://github.com/Wanteen/COF-ML-Tutorial.git',repo],check=True)
else: subprocess.run(['git','-C',repo,'pull'],check=True)
os.chdir(repo); print('Repository ready:',os.getcwd())

# %% [markdown]
# 课程索引见 [notebooks/README.md](https://github.com/Wanteen/COF-ML-Tutorial/blob/main/notebooks/README.md)。
