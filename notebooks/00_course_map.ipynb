# %% [markdown]
# # COF × Machine Learning 入门路线
#
# 目标：让刚入学的研究生在不依赖本地 GPU 环境的情况下，理解并亲手完成：
#
# 1. Python 科学计算；
# 2. 监督学习与模型评价；
# 3. 材料结构表示；
# 4. COF 描述符构建；
# 5. COF 性质预测；
# 6. 图神经网络的基本思想；
# 7. 机器学习势（MLFF）的基本使用。
#
# 本课程优先支持 **Google Colab**。
# 建议每个 Notebook 都完成“必做题”，再进入下一节。

# %%
import sys, platform
print("Python:", sys.version)
print("Platform:", platform.platform())

# %% [markdown]
# ## 你最终应该能回答的问题
#
# - 一个 CIF 文件如何变成机器学习输入？
# - composition descriptor、geometric descriptor、graph representation 有什么区别？
# - 为什么随机划分数据可能高估 COF 模型泛化能力？
# - MAE、RMSE、R² 分别意味着什么？
# - 什么是 data leakage？
# - 什么时候该使用 Random Forest / XGBoost，什么时候需要 GNN？
# - MLFF 为什么能够用于结构优化和分子动力学？
# - 对 COF 数据，孔径、孔隙率、密度、元素组成和官能团信息分别提供什么信息？

# %% [markdown]
# ## 课程项目
#
# 最终项目使用 `Wanteen/CURATED-COFs` 中的 COF 数据作为真实结构来源。
# 重点不是追求一个“漂亮的 R²”，而是建立一个可解释、可复现、能避免数据泄漏的计算材料 ML workflow。
